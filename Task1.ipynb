# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
t=pd.read_csv("Employee Attrition.csv")
t.head
print(t.isnull())
# Out:
#        Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       False               False            False           False
# 1       False               False            False           False
# 2       False               False            False           False
# 3       False               False            False           False
# 4       False               False            False           False
# ...       ...                 ...              ...             ...
# 15782   False               False            False           False
# 15783   False               False            False           False
# 15784   False               False            False           False
# 15785   False               False            False           False
# 15786   False               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     False               False          False
# ...

# %%
a=t.isnull().sum()
t.dropna()
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
total=np.product(t.shape)
t_missing=a.sum()
(t_missing/total)*100
# Out:
# 4.991448660290112

# %%
t.fillna(method='bfill',axis=0).fillna(0)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
t['satisfaction_level'].value_counts().plot(kind='bar',color=['#d5e0fe','#656371','#ff7369'])
# Out:
# <Axes: >

# %%
sns.set_style('dark')
sns.scatterplot(x=t.time_spend_company,y=t.satisfaction_level,hue=t.number_project)
# Out:
# <Axes: xlabel='time_spend_company', ylabel='satisfaction_level'>

# %%
correlation_matrix=t.corr()
# Out:
# C:\Users\Chitti\AppData\Local\Temp\ipykernel_17828\3576469749.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=t.corr()

# %%
correlation_matrix
# Out:
#                          Emp ID  satisfaction_level  last_evaluation  \
# Emp ID                 1.000000            0.045841        -0.018168
# satisfaction_level     0.045841            1.000000         0.105021
# last_evaluation       -0.018168            0.105021         1.000000
# number_project        -0.012124           -0.142970         0.349333
# average_montly_hours  -0.009850           -0.020048         0.339742
# time_spend_company     0.144159           -0.100866         0.131591
# Work_accident          0.015931            0.058697        -0.007104
# promotion_last_5years  0.088994            0.025605        -0.008684
#
#                        number_project  average_montly_hours  \
# Emp ID                      -0.012124             -0.009850
# satisfaction_level          -0.142970             -0.020048
# last_evaluation              0.349333              0.339742
# number_project               1.000000              0.417211
# ...

# %%
sns.set_style('dark')
sns.heatmap(correlation_matrix,annot=True,linecolor='white',linewidths=5,cmap="YlGnBu")
# Out:
# <Axes: >
